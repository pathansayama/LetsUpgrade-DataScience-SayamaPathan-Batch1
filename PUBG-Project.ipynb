# %% [markdown]
# <a href="https://colab.research.google.com/github/pathansayama/LetsUpgrade-DataScience-SayamaPathan-Batch1/blob/main/PUBG-Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library()
library(readr)
library(dplyr)
library(gridExtra)
library(ggplot2)
library(data.table)
library(GGally)
library(caret)
library(MASS)
library(h2o)
library(lime)

library(pdp)
library(ranger)
library(corrplot)

# %%
import random

print("="*41)
print(" ")
class goblin:
    def __init__(self,life,damage,ability):
        self.life=life
        self.damage=damage
        self.ability=ability     

goblin.life=random.choice(list(range(1000,3000)))
goblin.damage=random.choice(list(range(200,300)))
goblin.ability="Magical Powers ! "

#==========================================

class dwarf:
    def __init__(self,life,damage,ability):
        self.life=life
        self.damage=damage
        self.ability=ability
    

dwarf.life=random.choice(list(range(1000,3000)))
dwarf.damage=random.choice(list(range(200,300)))
dwarf.ability="Heavily trained army"

#==========================================

choice=str(input(" ")).lower()
x=str(input()).lower()
#==========================================

if (choice=="goblin"):
    print("A goblin is a monstrous creature from European Folklore, first attested in stories from the Middle ages. They are ascribed various and conflicting abilities, temperaments and appearances depending on the story and country of origin. They are almost always small and grotesque, mischievous or outright malicious, and greedy, especially for gold and jewelry. They often have magical abilities similar to a fairy or demon.")
    print(" ")
    print("Goblin's life is : ",goblin.life)
    print(" ")
    print("Goblin's damage is : ",goblin.damage)
    print(" ")
    print("Goblin's ability is : ",goblin.ability)
    print("="*41)
    print("Your opponent is : Dwarf")
    print(" ")
    print("Dwarf's life is : ",dwarf.life)
    print(" ")
    print("Dwarf's damage is : ",dwarf.damage)
    print(" ")
    print("Dwarf's ability is : ",dwarf.ability)
    
    
    

#==========================================

elif(choice=="dwarf"):
    print("In Germanic Mythology, a dwarf is a human-shaped entity that dwells in mountains and in the earth, and is variously associated with wisdom, mining, and crafting. Dwarfs are sometimes described as short and ugly, although some scholars have questioned whether this is a later development stemming from comical portrayals of the beings.Dwarfs continue to be depicted in modern popular culture in a variety of media.")
    print(" ")
    print("Dwarf's life is : ",dwarf.life)
    print(" ")
    print("Dwarf's damage is : ",dwarf.damage)
    print(" ")
    print("Dwarf's ability is : ",dwarf.ability)
    print(" ")
    print("="*41)
    print("Your opponent is : Goblin")
    print(" ")
    print("Goblin's life is :",goblin.life)
    print(" ")
    print("Goblin's damage is : ",goblin.damage)
    print(" ")
    print("Goblin's ability is : ",goblin.ability)
print(" ")


#==========================================


gob="Goblin Wons!"
dwf="Dwarf Wons!"
print("-"*41)
print(" ")
print("Guess who will win?")
print(" ")
print("-"*41)
print(" ")
a=goblin.damage
aa=goblin.life
b=dwarf.damage
bb=dwarf.life
print("Your answer was : ",x)
print(" ")



#==========================================




if (a>b) and (aa>bb):
    print(gob)
    if (x=="goblin"):
        print(" ")
        print("Your answer was correct !")
    else :
        print("Your answer was wrong !")
        
elif (b>a) and (bb>aa):
    print(dwf)
    if(x=="dwarf"):
        print(" ")
        print("Your answer was correct !")
    else :
        print(" ")
        print("Your answer was wrong !")
elif (a>120) and (aa>1000):
    print(gob)
    if (x=="goblin"):
         print(" ")
         print("Your answer was correct !")
    else :
       print("Your answer was wrong !")
elif (b>120) and (bb>1000):
    print(dwf)
    if(x=="dwarf"):
        print(" ")
        print("Your answer was correct !")
    else :
        print("Your answer was wrong !")
elif (a>b)and(bb>aa):
    print(gob)
    if (x=="goblin"):
        print(" ")
        print("Your answer was correct !")
    else :
        print(" ") 
        print("Your answer was wrong !")
elif (b>a)and(aa>bb):
    print(dwf)
    if(x=="dwarf"):
        print(" ")
        print("Your answer was correct !")
    else :
        print(" ")
        print("Your answer was wrong !")
print(" ")


print("="*41)
# Out:
# ...
#
#  Goblin
# Dwarf
# A goblin is a monstrous creature from European Folklore, first attested in stories from the Middle ages. They are ascribed various and conflicting abilities, temperaments and appearances depending on the story and country of origin. They are almost always small and grotesque, mischievous or outright malicious, and greedy, especially for gold and jewelry. They often have magical abilities similar to a fairy or demon.
#
# Goblin's life is :  2990
#
# Goblin's damage is :  251
#
# Goblin's ability is :  Magical Powers !
# ...
# Your opponent is : Dwarf
#
# Dwarf's life is :  1769
#
# Dwarf's damage is :  297
#
# Dwarf's ability is :  Heavily trained army
#
# -----------------------------------------
#
# Guess who will win?
#
# -----------------------------------------
#
# Your answer was :  dwarf
#
# Goblin Wons!
# Your answer was wrong !
#
# ...
